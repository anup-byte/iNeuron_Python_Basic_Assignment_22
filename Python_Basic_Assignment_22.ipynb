# %% [markdown]
# Q1. What is the result of the code, and explain?

# %%
X = 'iNeuron'

def func():
    print(X)

# %%
func()
# Out:
# iNeuron

# %% [markdown]
# X is a global variable so when the func() function is called it print the global variable X

# %% [markdown]
# Q2. What is the result of the code, and explain?

# %%
X = 'iNeuron'

def func():
    X = 'NI!'

# %%
func()

# %%
print(X)
# Out:
# iNeuron

# %% [markdown]
# When the function func() is called nothing is returned or printed as the function neither return nor print
# anything
# When the X is printed, X outside the function which is global in scope is printed. X which is inside the
# function has a local scope and does not get called.

# %% [markdown]
# Q3. What does this code print, and why?

# %%
X = 'iNeuron'

def func():
    X = 'NI!'
    print(X)

# %%
func()
# Out:
# NI!

# %%
print(X)
# Out:
# iNeuron

# %% [markdown]
# When the function func() is called, the X which is defined inside the function is printed because the scope of
# X defined inside the function is local.
# When the X is printed outside the function global X is printed which is defined outside the function

# %% [markdown]
# Q4. What output does this code produce? Why?

# %%
X = 'iNeuron'

def func():
    global X
    X = 'NI'

# %%
func()

# %%
print(X)
# Out:
# NI

# %% [markdown]
# When func() is called nothing is retured or printed but the varible X defined inside the function is global
# in scope. So, when the X is printed global X get printed

# %% [markdown]
# Q5. What about this code—what’s the output, and why?

# %%
X = 'iNeuron'

def func():
    X = 'NI'

# %%
def nested():
    print(X)
    nested()

# %%
nested()
# Out:
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# ...

# %%
func()

# %%
X
# Out:
# 'iNeuron'

# %% [markdown]
# Since a nested() function is defined inside the nested() function.So the function keeps on calling itself
# recursively till the maximum recursive depth reached.
#
# func() does not return anything
#
# When X is called golbal X is printed

# %% [markdown]
# Q6. How about this code: what is its output in Python 3, and explain?

# %%
def func():
    X = 'NI'
    def nested():
        nonlocal X
        X = 'Spam'
    nested()
    print(X)

# %%
func()
# Out:
# Spam

# %% [markdown]
# The nonlocal keyword won’t work on local or global variables and therefore must be used to reference variables
# in another scope except the global and local one. The nonlocal keyword is used in nested functions to reference
# a variable in the parent function.
#
# The nonlocal keyword is used to work with variables inside nested functions, where the variable should not
# belong to the inner function. The keyword nonlocal is use to declare that the variable is not local.

# %% [markdown]
# When the func() is called nested() function inside it returns X = 'Spam' and the same is printed
